# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: cycler>=0.10 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: numpy>=1.21 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: pillow>=8 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/prashant/cdac/Machine_Learning/Udemy_Jupyter_concept/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
x = dataset.iloc[: , 1:-1].values # features
y = dataset.iloc[:, -1].values  # dependent variable
# Out:
# [  45000   50000   60000   80000  110000  150000  200000  300000  500000
#  1000000]

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
x_poly=poly_reg.fit_transform(x)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
print(plt.__version__)
# Out:
# 3.8.4

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color ='red')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color ='red')
plt.plot(x,lin_reg_2.predict(x_poly),color='blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(x), max(x), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(x, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# /tmp/ipykernel_17604/2384935966.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(x), max(x), 0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
